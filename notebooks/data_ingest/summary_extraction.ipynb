# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../')


from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv(), override=True)

# %%
from src.preprocessor.preprocessing import FileIO, Utilities
from src.llm.llm_interface import LLM
from src.llm.llm_utils import get_token_count, load_azure_openai
from tqdm import tqdm
import tiktoken
from math import ceil

import os
import asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
long_summary = '''
In this episode of the Huberman Lab podcast, Dr. Andy Galpin, Professor of Kinesiology at Cal State 
University Fullerton, joins host Andrew Huberman to discuss optimal protocols for building strength and muscle 
growth. They begin by highlighting the importance of strength and hypertrophy training for everyone, not just 
athletes or those looking to build big muscles. They emphasize the benefits of strength training for neuromuscular 
aging, as strength and power decline faster than muscle mass with age. Additionally, they explain that strength 
training is the only exercise route to keep the nervous system healthy and young. They discuss the various 
adaptations that occur in the body to increase strength, such as improvements in neuromuscular activation, muscle 
contraction, and movement mechanics. 
'''

# %%
get_token_count(long_summary)
# Out:
# 160

# %%
data_path = '../../data/huberman_labs.json'
data = FileIO.load_json(data_path)

# %%
def extract_fields(data: list[dict], 
                   extract_keys: list[str]=['title','guest', 'content'], 
                  ) -> list[dict]:
    extracted_fields = []
    for d in data:
        extracted_fields.append({k:v for k,v in d.items() if k in extract_keys})
    return extracted_fields

# %%
episodes = extract_fields(data)

# %%
short_summary_extraction_system = '''
You are an expert at extracting high-level insights and important concepts from detailed reports or transcripts. 
Your main goal in life is to summarize the concepts found within episode transcripts from the Huberman Lab podcast. 
To aid in your summarization, context will be provided to you which will include the episode title as well as the guest.  
Do not include any extraneous information from the transcript such as giving thanks to corporate sponors.  
'''

# %%
long_summary_extraction_system = '''
Provide a comprehensive summary of the following Huberman Lab podcast episode.  
Ensure the summary includes relevant details and examples that support the main ideas, while avoiding 
any unnecessary information or repetition. The summary should provide a clear and accurate 
overview without omitting any important information. For context you will also be provided the 
episode title as well as the guest.  Do not include any extraneous information from the transcript such 
as giving thanks to corporate sponors.  Ensure that the summary is no more than 250 tokens.
'''

# %%
user_prompt = '''
Summarize at a high level, the content of the transcript. Do not go over 5 sentences in length. It is very important 
that you summarize the material in a condensed format. 
```
Title:\n
{title}
---------
Guest:\n
{guest}
---------
Transcript:\n
{transcript}
---------
```
Summary:
'''

# %%
def generate_user_prompt(data: list[dict], episode_num: int, n: int):
    title, guest, transcript = data[episode_num]['title'], data[episode_num]['guest'], data[episode_num]['content']
    return user_prompt.format(title=title, guest=guest, transcript=transcript, n=n)

# %%
# llm = LLM(model_name='azure/gpt-35-turbo-16k',
#           api_key=api_key,
#           api_version=api_version,
#           api_base=api_base)

llm = load_azure_openai(model_name='gpt-4')

# %%
def validate_token_count(system_message: str,
                         user_message: str,
                         threshold: int,
                         encoding: str='cl100k_base',
                         verbose: bool=True
                        ) -> str:
    '''
    Ensures that the length of the user_message does not 
    exceed the user-defined token threshold
    '''    
    system_tokens = get_token_count(system_message, return_tokens=True, verbose=False)
    user_tokens = get_token_count(user_message, return_tokens=True, verbose=False)
    sys_token_length, user_token_length = len(system_tokens), len(user_tokens)
    if verbose:
        print(f'Total system tokens: {sys_token_length}')
        print(f'Initial user tokens: {user_token_length}')
    if sys_token_length + user_token_length > threshold:
        user_tokens = user_tokens[:threshold - sys_token_length]
        encoder = tiktoken.get_encoding(encoding)
        user_message = encoder.decode(user_tokens)
        user_token_length = len(get_token_count(user_message, return_tokens=True, verbose=False))
    if verbose:
        print(f'Final user tokens: {user_token_length}')
        print(f'Total input tokens: {sys_token_length + user_token_length}')
    return user_message

# %%
test_prompt = generate_user_prompt(data, 10, 200)

# %%
user_ = validate_token_count(short_summary_extraction_system, test_prompt, threshold=16000, verbose=False)

# %%
# print(user_prompt)

# %%
async def get_summary(episode: dict, 
                      user_base: str, 
                      system_message: str,
                      max_tokens: int=200,
                      threshold: int=16000
                     ) -> str:
    title = episode['title']
    guest = episode['guest']
    transcript = episode['content']
    user_message = user_base.format(title=title, guest=guest, transcript=transcript, n=max_tokens)
    user_message = validate_token_count(system_message, user_message, threshold, verbose=False)
    summary = await llm.achat_completion(system_message, user_message, max_tokens=max_tokens, temperature=0, raw_response=False)
    return summary

# %%
user_prompt
# Out:
# '\nSummarize at a high level, the content of the transcript. Do not go over 5 sentences in length. It is very important \nthat you summarize the material in a condensed format. \n```\nTitle:\n\n{title}\n---------\nGuest:\n\n{guest}\n---------\nTranscript:\n\n{transcript}\n---------\n```\nSummary:\n'

# %%
test_sum = await get_summary(episodes[98], user_prompt, long_summary_extraction_system)

# %%
test_sum
# Out:
# 'In the Huberman Lab Podcast #94 titled "Fitness Toolkit: Protocol & Tools to Optimize Physical Health," Andrew Huberman discusses science-based tools to optimize physical health, covering various fitness aspects such as endurance, strength, flexibility, hypertrophy, and more. He proposes a general fitness protocol that individuals can adapt to pursue specific fitness goals such as increased strength or endurance. Huberman outlines his workout schedule, emphasizing training large muscle groups like legs and adjusting for recovery and biomechanical safety with activities such as heat-cold contrast sessions for recovery.\n\nThe podcast also explores the benefits of long endurance workouts, the importance of resistance training coupled with tailored sets and repetitions for hypertrophy or strength gains, and the significance of incorporating neck exercises for overall stability and safety. Huberman reinforces the necessity of balancing fitness types throughout the week, providing a foundation for full-body health.\n\nAdditionally, he announces the launch of the Huberman Lab Podcast premium channel, offering in-depth responses to listener questions and exclusive content. He discusses'

# %%
async def summary_tasks(episodes: list[dict], 
                        user_base: str, 
                        system_message: str, 
                        max_tokens: int=200,
                        threshold: int=16000, 
                        batch_size: int=10):
    batches = ceil(len(episodes)/batch_size)
    summaries = []
    for i in tqdm(range(batches)):
        batch = episodes[i*batch_size:(i+1)*batch_size]
        tasks = [get_summary(episode, user_base, system_message, max_tokens, threshold) for episode in batch]
        responses = await asyncio.gather(*tasks)
        summaries.extend(responses)
        # await asyncio.sleep(60)
    return summaries

# %%
# %%time
num_53 = asyncio.run(summary_tasks(episodes[53:54], user_prompt, short_summary_extraction_system, threshold=16000, batch_size=10))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:05<00:00, 65.79s/it]
# CPU times: user 95.6 ms, sys: 7.19 ms, total: 103 ms
# Wall time: 1min 5s

# %%
first_20 = test_run + test_run2

# %%
mid = first_20 + subset_20_100

# %%
final = mid + last_93

# %%
final_98 = '''
In the Huberman Lab Podcast #94 titled "Fitness Toolkit: Protocol & Tools to Optimize Physical Health," Andrew Huberman discusses science-based tools to optimize physical health, covering various fitness aspects such as endurance, strength, flexibility, hypertrophy, and more. He proposes a general fitness protocol that individuals can adapt to pursue specific fitness goals such as increased strength or endurance. Huberman outlines his workout schedule, emphasizing training large muscle groups like legs and adjusting for recovery and biomechanical safety with activities such as heat-cold contrast sessions for recovery.\n\nThe podcast also explores the benefits of long endurance workouts, the importance of resistance training coupled with tailored sets and repetitions for hypertrophy or strength gains, and the significance of incorporating neck exercises for overall stability and safety. Huberman reinforces the necessity of balancing fitness types throughout the week, providing a foundation for full-body health.\n\nAdditionally, he announces the launch of the Huberman Lab Podcast premium channel, offering in-depth responses to listener questions and exclusive content.
'''

# %%
final[98]
# Out:
# 'In the Huberman Lab Podcast #94 titled "Fitness Toolkit: Protocol & Tools to Optimize Physical Health," Andrew Huberman discusses science-based tools to optimize physical health, covering various fitness aspects such as endurance, strength, flexibility, hypertrophy, and more. He proposes a general fitness protocol that individuals can adapt to pursue specific fitness goals such as increased strength or endurance. Huberman outlines his workout schedule, emphasizing training large muscle groups like legs and adjusting for recovery and biomechanical safety with activities such as heat-cold contrast sessions for recovery.\n\nThe podcast also explores the benefits of long endurance workouts, the importance of resistance training coupled with tailored sets and repetitions for hypertrophy or strength gains, and the significance of incorporating neck exercises for overall stability and safety. Huberman reinforces the necessity of balancing fitness types throughout the week, providing a foundation for full-body health.\n\nAdditionally, he announces the launch of the Huberman Lab Podcast premium channel, offering in-depth responses to listener questions and exclusive content.'

# %%
FileIO.save_as_json('/tmp/short_summaries.json', final, overwrite=True)
# Out:
# 2024-04-26 04:15:39.948 | INFO     | src.preprocessor.preprocessing:save_as_json:111 - Data saved as json file here: /tmp/short_summaries.json

# %%
old_summaries = [d['summary'] for d in data]

# %%
import pandas as pd

old_lens = list(map(len, old_summaries))
new_lens = list(map(len, final))
old_df = pd.DataFrame(old_lens)
new_df = pd.DataFrame(new_lens)

# %%
for i, d in enumerate(episodes):
    guest = d['guest']
    print(f'GUEST: {guest}')
    print(final[i])
    print('-'*100)
# Out:
# GUEST: Dr. Matthew Walker
# In this episode of the Huberman Lab podcast, Andrew Huberman interviews Dr. Matthew Walker, a professor of neuroscience and psychology, and the director of the Center for Sleep Science at the University of California, Berkeley. The episode marks the beginning of a six-episode series on sleep. In this episode, they discuss the importance of sleep and what happens when we don't get enough quality sleep. They also touch on the different sleep stages, such as non-rapid eye movement (non-REM) sleep and rapid eye movement (REM) sleep. They explore the theory that yawning is a way for the brain to cool down and the impact of body position on sleep. They also discuss the concept of "great sleep" versus "mediocre sleep" and the consequences of not getting enough quality sleep. Overall, the episode provides a comprehensive introduction to the topic of sleep and sets the stage for the upcoming episodes in the series, which will cover various aspects of sleep and offer practical tools for improving sleep.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this Huberman Lab podcast episode, Andrew Huberman discusses the benefits and risks of peptide therapeutics for physical and mental health. Peptides are small proteins made up of chains of amino acids, and they play various roles in the body. For tissue healing and repair, BPC-157 is a synthetic peptide that promotes angiogenesis and fibroblast migration. It can be used to accelerate the healing of injuries, but caution should be taken as it may promote tumor growth. Another peptide called thymosin beta-4 (TB-500) is also used for tissue rejuvenation and repair. It increases the growth of various cell types and stimulates the growth of new blood vessels to the injury site. However, like BPC-157, TB-500 may raise concerns regarding tumor growth. There are also peptides that stimulate the release of growth hormone, which can enhance metabolism and muscle growth. Category one peptides, such as sermorelin and tesamorelin, are FDA approved and function by mimicking the natural release of growth hormone in the body. They increase growth hormone and IGF-1, providing benefits such as fat loss and increased muscle growth. Category two peptides, like hexarelin and ipamorelin, stimulate growth hormone release by mimicking or stimulating the hormone ghrelin. However, they may also lead to increased hunger and anxiety. These peptides require careful consideration and should be used under the guidance of a physician. Huberman advises against purchasing peptides from dubious sources and emphasizes the importance of working with a board-certified physician to ensure safety and efficacy.
# ----------------------------------------------------------------------------------------------------
# GUEST: Asi Wind
# The guest of this episode is Asi Wind, one of the top magicians and mentalists in the world. The discussion focuses on how magic and mentalism can reveal aspects of human perception and memory. Asi's tricks illustrate concepts such as how memories are formed, how emotions and storytelling can shape perception, and the role of empathy in magic. Asi explains that skilled magicians can manipulate perception and create false memories by understanding how people think and filling in the gaps in their perception. He also highlights the importance of connecting with the audience and creating a sense of wonder and collaboration. Asi emphasizes that magic is not about fooling people, but about providing a sense of amazement and creating a shared experience. The conversation delves into the neuroscience of learning, memory, and creativity, and how magic can tap into these processes. Asi shares insights from his mentors and explains how magic distinguishes itself as a unique art form that plays with the boundaries between reality and illusion.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Dr. Andrew Huberman hosts a live event in Melbourne, Australia, featuring a lecture followed by a lively Q&A session with the audience. The topics covered include ways to prevent dementia, increasing willpower, reducing the effects of disruption to circadian rhythm in shift workers, mindfulness practices such as non-sleep deep rest, strategies to stop mindlessly scrolling on phones, dream clinical trials, and more. Dr. Huberman also encourages audience participation and values different perspectives on various subjects, including genetics, trauma, consciousness, and the microbiome. He emphasizes the need for collective efforts to address important questions in the scientific community and advocates for open dialogue and communication in the field. Overall, the episode provides valuable insights into neuroscience, mental health, and well-being, illustrating the impact of science-based tools on everyday life.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. E.J. Chichilnisky
# In this Huberman Lab podcast episode, Dr. E.J. Chichilnisky, a professor of neurosurgery, ophthalmology, and neuroscience at Stanford University, discusses his research on visual perception and neural prostheses. Dr. Chichilnisky focuses on understanding how the brain encodes visual information and applying that knowledge to design robotic eyes that can restore vision in blind individuals. He explains that vision begins in the retina, a sheet of neural tissue at the back of the eye that captures light and transforms it into electrical signals. The retina contains different cell types, such as photoreceptor cells, which detect light, and retinal ganglion cells, which send visual information to the brain. Dr. Chichilnisky's research aims to understand the function and electrical properties of these cell types to develop devices that can restore vision. He describes the process of obtaining retinas for research, which involves working with organ donation centers. Once in the lab, the retinas are placed on electrode arrays to record their electrical signals and study their responses to different visual stimuli. Dr. Chichilnisky acknowledges that while the retina is the best understood part of the brain, there are still mysteries to uncover, such as the functions of certain cell types and how the brain integrates visual signals. He discusses the potential for neuroengineering to restore vision and enhance human capabilities. By designing electronic implants that can stimulate specific cell types in the retina, it may be possible to bypass damaged photoreceptor cells and send visual signals directly to the retinal ganglion cells. However, Dr. Chichilnisky emphasizes the need to develop devices that respect the complex circuitry of the retina, as existing implants are too crude to replicate natural vision. His goal is to create an artificial retina that can restore high-quality vision by stimulating different cell types independently and delivering visual information in a way that resembles the natural signal sent to the brain. This work not only has the potential to restore vision in blind individuals, but also has broader implications for understanding brain function and developing neuroengineering technologies for other brain areas.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Cal Newport
# In this Huberman Lab podcast episode, Dr. Cal Newport, a computer science professor at Georgetown University, discusses strategies for enhancing focus and improving productivity. Dr. Cal Newport is the author of several best-selling books, including "Deep Work: Rules for Focus Success in a Distracted World" and "Slow Productivity: The Lost Art of Accomplishment Without Burnout." The conversation explores practical steps individuals can take to enhance their level of focus, productivity, and creativity. Newport emphasizes the importance of eliminating distractions, such as social media, smartphones, and excessive emails, in order to optimize cognitive performance. He suggests creating specific protocols for different types of tasks and using specialized tools, like whiteboards and notebooks, to maximize focus and efficiency. Newport also highlights the concept of active recall, which involves replicating and recalling information to improve learning. He discusses the difference between deliberate practice and flow, explaining that deep work requires intense concentration rather than losing track of time. Newport also cautions against the addictive nature of smartphones and social media, and suggests that individuals reconsider unrestricted internet usage, particularly among young people. By prioritizing deep work and minimizing distractions, Newport asserts that individuals can improve their cognitive performance and achieve their best possible work.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, neurobiologist Andrew Huberman discusses the power of placebo effects and how they can change our biology and psychology. He explains that placebo effects, nocebo effects, and belief effects all stem from our brain's ability to form expectations and actually change our physiological functions. Huberman provides examples from scientific studies, such as how placebos can change dopamine release in the brain and reduce symptoms of Parkinson's disease. He also discusses belief effects and their ability to impact hormone release and physiological responses in the body. Huberman emphasizes that placebo effects are not just psychological, but actually involve neural circuits in the brain. He highlights that placebo, nocebo, and belief effects can have a significant impact on our mental health, physical health, and performance. Ultimately, understanding these effects can provide insights into how we can leverage them for our well-being.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Dr. Andrew Huberman answers various questions from listeners and provides science-based advice on topics such as sleep, vertigo, traumatic brain injury (TBI), OCD, gut-brain axis, and more. Regarding maintaining health pillars while traveling, Dr. Huberman suggests getting morning sunlight, using red lights in the evening to promote sleep, staying regimented about exercise, shifting circadian rhythm with morning sunlight, movement, social engagement, and caffeine, and practicing stress control with non-sleep deep rest (NSDR) or yoga nidra protocols. He also discusses optimal sleep duration, stating that the quantity, quality, regularity, and timing of sleep are important. He explains that five to six hours of sleep can be enough if you don't experience excessive daytime sleepiness and have sufficient mental and physical energy throughout the day. For individuals with sleep issues, Dr. Huberman recommends practicing NSDR upon waking up or during the day to recover missed sleep and improve the ability to fall and stay asleep. He also clarifies that excessive waking during the night or multiple trips to the restroom may indicate a need for improvement. On the topic of vertigo, Dr. Huberman explains that it is caused by miswiring in the basal ganglia and how to anchor the visual part of the vestibulo-ocular reflex by fixating on a distant point. When asked about recovering from poor sleep, poor diet, and TBI early in life, he highlights the importance of neuroplasticity and recommends adopting healthy habits in the present instead of dwelling on the past. For optimizing brain function, he advises adequate sleep, avoiding excessive use of antibiotics and antiseptics, and consuming fermented foods for gut-brain axis health. Dr. Huberman also discusses the benefits of fish oil for brain and body health, recommends getting hormone levels checked regularly after the age of 40, and suggests brushing the tongue gently with a separate soft toothbrush to maintain oral health. He emphasizes the importance of oral health for overall well-being and its connections to cardiovascular and brain health.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Becky Kennedy
# In this episode of the Huberman Lab podcast, Dr. Andrew Huberman interviews Dr. Becky Kennedy, a clinical psychologist specializing in parent-child relationships. Dr. Kennedy emphasizes that the insights shared in this episode are relevant not just to parents, but also to anyone in relationships of all kinds, including romantic partnerships, friendships, and workplace relationships. She highlights two key elements of positive parenting: setting healthy boundaries and offering empathy and validation. Dr. Kennedy defines boundaries as statements that communicate what one will do, requiring the other person to do nothing. She explains that boundaries keep individuals connected to themselves and their values, while also ensuring the safety of children. Empathy and validation, on the other hand, involve recognizing and understanding the other person's feelings and experiences as real, regardless of whether one agrees with them. Dr. Kennedy emphasizes the importance of providing specific validation and empathy to children in moments of difficulty, while still maintaining boundaries. She believes that children crave both boundaries and connection, as boundaries communicate protection and connection establishes a sense of being seen and understood. The podcast also touches on the topic of rewards, where Dr. Kennedy challenges the common belief that rewards are necessary for motivating children. She argues that rewarding behavior can lead to excessive dependence on rewards and diminishes intrinsic motivation. Instead, she suggests focusing on fostering a sense of purpose and contribution in children, encouraging them to recognize the impact they have on the world around them. The conversation also touches on topics such as impingement, the importance of repair in relationships, and the power of saying "I believe you" to validate someone's experience and build their confidence. Overall, the discussion provides helpful insights and strategies for building successful parent-child relationships and improving relationships of all kinds.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Mark D'Esposito
# Dr. Mark D'Esposito, a neurologist and professor at the University of California, Berkeley, discusses the neural circuits controlling executive function and memory. Executive function refers to the cognitive strategies we use to carry out specific tasks and is crucial for daily life. Dr. D'Esposito explains that the frontal lobes, specifically the prefrontal cortex, play a key role in executive function and memory. He describes the frontal lobes as the "CEO" or conductor of the brain, responsible for controlling and guiding the rest of the brain. Dr. D'Esposito also highlights the importance of dopamine in executive function and working memory. He explains that dopamine acts as a modulator to help maintain persistent neural activity in the frontal lobes during working memory tasks. He discusses how dopamine depletion impairs working memory, while increasing dopamine levels can improve working memory. However, he notes that individual baseline levels of dopamine can vary, and there is currently no reliable way to measure dopamine levels in individuals. Dr. D'Esposito also mentions that some pharmaceutical companies have not shown interest in developing drugs to improve cognitive function, despite the potential benefits. He suggests that a combination of neuromodulators, including dopamine, norepinephrine, serotonin, and acetylcholine, may be more effective in optimizing cognitive function. However, further research is needed to determine the ideal combination of these neurotransmitters and to better understand the individual's neurochemistry in order to provide personalized treatments for cognitive function.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Andrew Huberman discusses the importance of oral health and its impact on overall bodily health. He introduces oral health as the seventh pillar of mental health, physical health, and performance. Huberman explains that oral health goes beyond tooth health and breath freshness, as it affects various bodily compartments, including cardiovascular, metabolic, brain, and gum health. He discusses the biology of teeth, emphasizing the potential for cavities to be filled in and the importance of saliva in maintaining oral and gut microbiome health. Huberman also addresses common oral health concerns, such as the use of fluoride, the impact of stimulants, smoking and vaping, and the effects of acidic foods and sugar. He highlights the significance of saliva production, intermittent fasting, and nighttime oral hygiene practices in maintaining optimal oral health. The episode concludes by discussing the dos and don'ts for preserving oral health and the recommended frequency of brushing and flossing.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Kay Tye
# In this episode of the Huberman Lab podcast, Dr. Kay Tye, a professor of neuroscience, discusses her research on social interactions and emotions. She explains that the amygdala, a brain area most commonly associated with fear, actually plays a role in both positive and negative emotional processing. By studying neurons in the amygdala, Dr. Tye discovered so-called loneliness neurons that are activated when individuals are not experiencing fulfilling social interactions. She also discusses the concept of social homeostasis, which refers to the body's sense of whether it is receiving enough, not enough, or just enough social interaction, regardless of whether one is an introvert or extrovert. Dr. Tye's research has shown that social isolation and loneliness have negative health consequences, leading to shortened lifespans, increased mood disorders, and increased morbidity and mortality for certain diseases. She emphasizes the importance of understanding the neurochemical, neural circuit, and hormonal aspects of social interactions in order to promote mental health and build healthy social interactions. Dr. Tye notes that while social media can provide a form of social contact, it is often asynchronous and lacks true interbrain synchrony, which is an important component of meaningful social interactions. Furthermore, she discusses the potential negative impact of social media, such as the feeling of exclusion when seeing others' posts and the lack of real connection in the absence of one-on-one or in-person interactions. Overall, Dr. Tye's research highlights the significance of social interaction for individuals and the consequences of social isolation on mental health and overall well-being.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Dr. Andrew Huberman answers an Ask Me Anything (AMA) question about the benefits and risks of fluoride in our drinking water. He explains that fluoride has clear benefits for tooth strength and cavity prevention, but excessive consumption can be harmful as it is a poison at certain levels. Dr. Huberman discusses the ongoing controversy surrounding fluoride in drinking water, with some people filing lawsuits to have fluoride removed and others suing because they believe there isn't enough fluoride. The use of fluoride in drinking water started in the 1950s as a low-cost approach to reduce tooth decay and cavities. Dr. Huberman emphasizes the importance of understanding the dosage and how it can vary depending on the concentration in tap water, the amount consumed, and individual body weight. He mentions that high levels of fluoride can disrupt thyroid hormone function and potentially cause neurotoxicity. However, he cautions that the evidence for neurotoxicity is still highly debated. Dr. Huberman advises listeners to find out the fluoride concentration in their tap water through testing and to make an informed decision about filtering based on their level of concern and disposable income. He also mentions that there are other natural ways to strengthen teeth and fill in cavities, which he will discuss in a future episode on oral health. Dr. Huberman shares his personal experience of being inadvertently poisoned by fluoride during a dental treatment as a child. He concludes by recommending individual research, awareness of fluoride levels, and personal choices based on the understanding of potential risks and benefits. The episode ends with information about the Huberman Lab Premium channel, which supports the podcast and funds research on mental health, physical health, and performance, with the Tiny Foundation matching every dollar raised for research.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this Huberman Lab podcast episode, Andrew Huberman discusses working memory and its relationship to attention. Working memory allows us to hold small amounts of information in our minds for short periods of time. Huberman explains that working memory is different from long-term memory, which involves the storage of facts and procedural skills. Working memory also differs from short-term memory, which is the temporary storage of information before it is either discarded or passed into long-term memory. Huberman emphasizes that the formation of short and long-term memories involves neuroplasticity, which is the brain's ability to change in response to experience. He explains that neuroplasticity can occur through long-term potentiation or long-term depression, in addition to other forms of plasticity. However, working memory does not heavily rely on neuroplasticity. Instead, working memory is associated with dopamine levels in the brain, particularly in the prefrontal cortex. Huberman describes studies that have found a correlation between higher dopamine levels and better working memory capacity. He also discusses experiments where increasing or decreasing dopamine levels in the brain affected working memory performance. Huberman notes that the relationship between dopamine and working memory follows an inverted U-shaped curve. Too little dopamine results in low working memory capacity, increasing dopamine levels improves working memory up to a certain point, but excessive dopamine levels can actually impair working memory. Huberman suggests that non-sleep deep rest techniques like yoga nidra may increase dopamine levels and improve working memory. He explains that other activities like cold showers may also increase dopamine and enhance focus and attention. However, he emphasizes the importance of individual differences and urges listeners to pay attention to their own working memory performance and dopamine levels to determine which strategies are most effective for them.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Peter Attia
# In this episode of the Huberman Lab Podcast, Andrew Huberman discusses two papers related to mental health and cancer treatments with Dr. Peter Attia. The first paper focuses on the effects of light exposure on mental health, highlighting the importance of getting bright light in one's eyes throughout the day and maximizing darkness at night. The data shows that light and dark have independent and additive effects on mental health, with bright light exposure associated with reduced symptoms of many mental health disorders. The second paper discusses novel treatments for cancer, emphasizing the role of the immune system in cancer treatments and the potential for future technologies. The discussion points out the importance of considering light exposure and maximizing darkness at night for mental health and the potential benefits of certain cancer treatments. The findings highlight the significance of light exposure and dark exposure in everyday life and potential applications for improving mental health and cancer treatments.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Sean Mackey
# In this episode of the Huberman Lab podcast, Dr. Andrew Huberman interviews Dr. Sean Mackey about pain and its management. Pain is a complex and subjective experience that helps protect us from harm. It involves both sensory and emotional components and varies among individuals. The physical sensation of pain arises from nociceptors that respond to various stimuli, such as heat, cold, and pressure. These signals then travel to the brain where pain is experienced. Pain thresholds differ between individuals, influenced by factors like genetics, gender, and emotional state. For example, men generally have higher pain thresholds than women for certain stimuli. Pain management can involve a range of strategies, including both chemical and mechanical interventions. Chemical interventions include medications like NSAIDs, acetaminophen, and opioids, while mechanical interventions involve techniques like rubbing, applying hot or cold stimuli, or using transcutaneous electrical neurostimulation (TENS) devices. The use of heat or cold can reduce pain by affecting inflammation, numbing nerves, and increasing blood flow to affected areas. Other strategies for pain management include attentional distraction, mindfulness and acceptance-based approaches, and cognitive reframing. These methods aim to reduce pain perception, provide relief, and improve overall well-being. It's important to understand the difference between being hurt and being harmed, both physically and emotionally, in order to effectively manage and treat pain.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this podcast episode, Andrew Huberman discusses how to prevent and treat colds and flus. He provides insights into the immune system and explains how it works to fight off viruses. Huberman emphasizes the importance of the physical barrier of the skin and mucosal lining in preventing viruses from entering the body. He also mentions the innate immune system, which launches a general response to combat viruses. Additionally, Huberman explains the role of the adaptive immune system in producing antibodies specific to the virus that has entered the body. He highlights the importance of maintaining a healthy immune system to prevent and fight off colds and flus. Huberman also touches on the importance of sleep, exercise, and adequate nutrition in supporting the immune system. He dispels common myths about treatments for the common cold and flu and provides science-supported strategies for preventing and treating these illnesses.
# ----------------------------------------------------------------------------------------------------
# GUEST: David Goggins
# In this episode of the Huberman Lab podcast, Andrew Huberman interviews David Goggins, a retired Navy SEAL, ultra marathon runner, and best-selling author. Goggins shares his personal journey of overcoming immense challenges and transforming himself into a successful individual. He discusses how his difficult childhood and negative environment fueled his desire to change and become the best version of himself. Goggins also talks about the power of willpower and the importance of embracing discomfort and friction in order to grow. He explains that true growth comes from doing the things that you don't want to do and constantly pushing yourself out of your comfort zone. Goggins reveals that building inner strength and discipline requires daily effort and a willingness to constantly challenge yourself. He emphasizes the importance of self-examination and understanding who you are in order to reach your full potential. Goggins also touches on the scientific mechanisms underlying willpower and discusses his current focus on studying medicine to become a paramedic. He shares his belief that there are no shortcuts or hacks to success and that true growth comes from hard work and embracing the pain. Throughout the episode, Goggins exhibits his intense dedication and passion, highlighting the importance of understanding and accepting one's weaknesses and using them as fuel for growth.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# The Huberman Lab podcast episode titled "AMA #14: 2023 Philanthropy, Evening Routine, Light Therapy, Health Metrics & More" features Andrew Huberman discussing various topics. Initially, Huberman expresses gratitude towards the support provided by the premium channel subscribers. He highlights the research projects funded by that support, including studies on mindset, intermittent fasting, immune system, eating disorders, and transcranial magnetic stimulation combined with psychedelic treatments. Following this, Huberman answers questions from listeners. He explains the significance of the anterior mid-singulate cortex, which is involved in embracing challenging endeavors. He suggests engaging in safe but uncomfortable challenges to stimulate the growth of this brain area. Huberman also shares his evening routine, emphasizing the importance of reducing exposure to bright lights in the evening and using red lights instead to promote relaxation and melatonin production. He adds that avoiding excessive fluid intake before bed and practicing relaxation techniques, such as deep breathing and hypnosis, can aid in falling back asleep if waking up in the middle of the night. Later, Huberman addresses strength training without hypertrophy for women, advising lower repetitions and heavier weights, while suggesting focusing on mind-muscle connection, unilateral movements, and long rest periods. He then discusses the benefits and considerations of undergoing full-body scan MRIs, highlighting their potential value in identifying underlying health issues. Additionally, Huberman expresses interest in creating an episode on dog wellness and communication, and encourages taking care of pets' health and adopting if possible. The episode concludes with Huberman answering various other questions related to health and fitness, providing insight and advice based on his expertise.
# ----------------------------------------------------------------------------------------------------
# GUEST: Rick Rubin
# In this episode of the Huberman Lab, Andrew Huberman interviews Rick Rubin, a renowned music producer and author. Rick answers questions from listeners about the creative process. They discuss practical aspects of creativity and offer insights into how to overcome creative blocks. Rick emphasizes the importance of staying true to oneself and not getting caught up in the fear of judgment or external expectations. He suggests approaching creativity as a devotional practice and treating it as a personal reflection of one's own experience. He also shares his perspective on meditation and its benefits for the creative process, as well as the importance of embracing uncertainty and staying open-minded. Rick discusses the impact of his work with artists like Johnny Cash and the significance of the artist's authenticity and point of view in creating meaningful art. They touch upon the influence of AI and new technology in the creative realm, with Rick expressing his curiosity about its potential impact. Throughout the conversation, Rick emphasizes the importance of tapping into one's sensitivity and connecting with oneself to nurture the creative process. Overall, the discussion explores the practical and philosophical aspects of creativity and offers valuable insights and advice for artists and creators.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Robert Lustig
# In this episode of the Huberman Lab Podcast, Dr. Robert Lustig, an endocrinologist and professor of pediatric endocrinology, discusses the impact of sugar and processed foods on health. He challenges the idea that a calorie is just a calorie, stressing that different types of nutrients affect the body differently. Dr. Lustig explains that not all calories are absorbed by the body, providing examples such as fiber in almonds, which forms a gel that prevents calorie absorption, and protein, which requires double the amount of energy to process compared to carbohydrates. He also highlights the damaging effects of fructose, stating that it causes insulin inhibition, leading to liver and kidney damage, as well as addiction-like responses in the brain. Dr. Lustig emphasizes the role of the food industry in promoting the misconception that all calories are equal and encourages a mindful approach to food choices.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Karen Parker
# In this Huberman Lab podcast episode, titled "Dr. Karen Parker: The Causes & Treatments for Autism," Dr. Karen Parker discusses the biological basis, causes, and treatments for autism. The incidence and diagnosis of autism have increased dramatically in recent years. Although detection and awareness have improved, the actual incidence of autism has also increased, with current rates showing that 1 in 36 US children have a diagnosis of autism. Autism is a behavioral diagnosis determined by experts who look for two core features: pervasive social interaction challenges and the presence of restricted repetitive behavior. While there is no blood test or biomarker for autism, studies have shown that autism is a highly heritable condition, with about 40-80% of autism being genetic in nature. Genetic studies have revealed that a large number of genes are altered or the proteins they code for in autism, including oxytocin and vasopressin. Oxytocin and vasopressin, both small peptides, are involved in social behavior and are highly evolutionarily conserved across species. In humans, oxytocin has been associated with mother-infant bonding, trust, and social connection. Various studies have explored the effects of oxytocin administration in individuals with autism, and while some studies have shown positive effects, others have shown no benefit. One study conducted by Dr. Parker examined the effects of oxytocin treatment in children with autism, specifically looking at baseline blood oxytocin levels. The results showed that children with lower pretreatment oxytocin levels had a greater benefit from the oxytocin intervention. However, a subsequent multi-site phase 3 trial using oxytocin failed to show significant benefit, possibly due to methodological differences and issues with protocol adherence. Overall, the effectiveness and safety of oxytocin treatment in autism remains an open question, with the need for further research and funding. Dr. Parker suggests that there may be subsets of individuals who could benefit from oxytocin treatment, particularly those with lower blood oxytocin levels. Attention is also given to the importance of early intervention and screening for autism, as early detection and treatment can significantly impact outcomes for children with autism.
# ----------------------------------------------------------------------------------------------------
# GUEST: Robert Greene
# Robert Greene, author of "The 48 Laws of Power," "The Laws of Human Nature," and "Mastery," is interviewed in this episode. Greene explores the concept of finding one's purpose and discusses how it is a difficult process for everyone. He emphasizes that each individual is unique and has their own source of power and purpose that should not be wasted. Greene suggests that individuals tap into their childhood experiences and passions to uncover their life's task or unique purpose. He also mentions that finding purpose provides direction, energy, and a sense of fulfillment. Throughout the episode, Greene also touches on the topics of power and seduction. He explains that power is a resource that allows individuals to influence and move others, while seduction involves vulnerability and letting someone into your psyche. He also notes that seduction goes beyond negative connotations and can be a positive experience of surrendering to someone's power. Ultimately, the episode highlights the importance of self-awareness, understanding one's desires and frustrations, and finding the balance between power dynamics in various relationships.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this AMA episode of the Huberman Lab Podcast, Dr. Andrew Huberman answers a question about why people tend to get more colds and flus during the winter months. He explains that there are several factors that contribute to this increase in illness. Firstly, the colder temperatures in winter cause people to spend more time indoors, which leads to closer proximity to others and a higher likelihood of transmission of viruses. Research has shown that physical proximity has a direct relationship with the transmission of colds and flus, with closer proximity increasing the probability of infection. Additionally, the indoor heating used during winter tends to dry out the nasal passages, which are a primary defense against colds and flus. This makes individuals more susceptible to infections. Dr. Huberman advises nasal breathing whenever possible, as the hairs and mucus in the nasal passages act as a physical trap for viruses. He also suggests using air humidifiers to keep the air sufficiently humidified, especially at night, to promote the health and resistance of the respiratory system. Being outdoors in the cold weather does not automatically increase the risk of colds and flus, but individuals should be mindful of drying out their nasal passages through hard breathing and take steps to rehydrate them afterwards. Dr. Huberman also mentions the importance of core body temperature in immune response to infections. Fever is an adaptation designed to destroy viruses, so reducing fever medication may hinder the immune system's ability to fight off infections. Finally, he discusses the potential benefits of deliberate cold exposure and cyclic hyperventilation breathing, but cautions against engaging in these practices if one is already contracting or has contracted a cold or virus. By understanding the factors that contribute to increased transmission of colds and flus during the winter months, individuals can take steps to mitigate their risk and protect their health.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Adam Grant
# In this episode of the Huberman Lab podcast, Dr. Adam Grant joins Andrew Huberman to discuss how to unlock one's potential, motivation, and unique abilities. They explore the topic of procrastination, highlighting the different reasons why people procrastinate and the relationship between procrastination and creativity. They also delve into the concept of intrinsic motivation and the importance of finding purpose and curiosity in tasks. The conversation touches upon the effects of extrinsic rewards on motivation and performance, emphasizing the need for autonomy and a sense of choice. They discuss the significance of focused attention, persistence, and having a growth mindset in achieving optimal performance. They also explore the importance of setting boundaries and uninterrupted time for deep work, and the potential impact of chronotypes on peak performance at different times of the day. The conversation concludes with an intriguing discussion about various creative processes and strategies for filtering and receiving feedback on ideas. Overall, the episode provides practical insights and tools based on scientific research to help individuals reach their goals, overcome challenges, and enhance their performance in various aspects of life.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, neurobiologist Andrew Huberman discusses a specific journaling practice that has been shown to have a significant impact on mental and physical health. The journaling protocol involves writing for 15 to 30 minutes for four consecutive days about the most difficult, traumatic, or highly stressful experience of one's life. The writing is done without pausing or editing, and participants are instructed to focus on the facts, emotions, and links to other areas of their life related to that experience. The research on this protocol, supported by over 200 peer-reviewed studies, demonstrates its positive effects on various aspects of health, including reducing anxiety, improving sleep, boosting immunity, and even providing relief for conditions such as fibromyalgia and autoimmune disorders. The journaling practice has been shown to improve memory, decision-making, and overall well-being. Huberman emphasizes that the protocol is separate from general discussions about the value of journaling, as it is a very specific method supported by rigorous scientific research. The episodes also dives into the underlying science behind the positive effects of this journaling method, including its impact on neuroplasticity, the rewiring and reshaping of the nervous system based on experience. Huberman explains that the emotional engagement during the writing exercise reduces the activity in the prefrontal cortex, the part of the brain associated with higher cognitive functions, while increasing the activity in subcortical areas related to emotional processing. The repeated writing about the traumatic experience over four sessions leads to more coherence in the narrative and a reduction in distress. Studies have also shown changes in immune system function with increased T-cell activation. Huberman concludes that this protocol provides an opportunity to tap into neuroplasticity and effectively reshape the narrative around traumatic experiences for improved mental and physical health.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# The Huberman Lab hosted a live event in Toronto, Ontario, which consisted of a lecture titled "The Brain-Body Contract," followed by a question and answer session. During the event, Dr. Andrew Huberman answered various questions from the audience. He discusses his motivation for the guest series with psychiatrist Paul Conti, emphasizing Conti's expertise in understanding and working with the unconscious mind. Huberman shares Conti's approach to accessing the unconscious through practices like mirror work, which entails staring into a mirror and reflecting on oneself and aspirations. He also highlights the importance of practices like morning routines and sleep for mental health and emotional resilience. Huberman provides insights on increasing neuroplasticity through various means, such as movements like the soleus push-up and engaging in activities like playing a musical instrument. He also suggests specific protocols to combat seasonal depression, including exposure to bright light early in the day. The discussion concludes with Huberman's morning meditation, which involves a perceptual exercise to shift between different time domains and expand one's perception of the world. Overall, the live event covers a range of topics related to mental health, emotional resilience, neuroplasticity, and well-being, providing practical insights and suggestions for listeners.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Natalie Crawford
# In this episode of the Huberman Lab podcast, Dr. Natalie Crawford, a medical doctor specializing in obstetrics and gynecology, reproductive endocrinology, and infertility, discusses various aspects of female hormone health and fertility. She covers topics such as puberty timing and its relationship to fertility, the effects of birth control on fertility and hormone health, measuring fertility, egg retrieval, and in-vitro fertilization. Dr. Crawford also delves into the role of nutrition and supplementation in fertility and hormone health. She emphasizes the importance of regular and predictable menstrual cycles as a vital sign of reproductive health. Dr. Crawford highlights that the age of puberty onset does not dictate the length of a woman's reproductive lifespan, as the number of eggs in the ovaries decreases continuously regardless of when puberty occurs. She also notes that the use of birth control does not affect the overall egg count or fertility. However, it may impact hormonal testing and should be considered when evaluating ovarian reserve. Dr. Crawford further discusses the impact of various substances on egg and sperm quality. Smoking cigarettes, vaping nicotine, and consuming cannabis and alcohol can all negatively affect egg and sperm development and quality. She explains that prolonged exposure to these substances may decrease fertility and increase the risk of miscarriage. Additionally, Dr. Crawford clarifies that contraceptive methods such as copper IUDs and progesterone-based IUDs work by affecting the uterine environment and do not directly alter egg quality or long-term fertility. She advises individuals considering the removal of an IUD to give their body time to normalize their menstrual cycle before attempting to conceive. Overall, Dr. Crawford provides valuable insights into female hormone health, fertility, and the impact of various factors on reproductive well-being.
# ----------------------------------------------------------------------------------------------------
# GUEST: Dr. Michael Eisenberg
# In this episode of the Huberman Lab podcast, Dr. Michael Eisenberg, an expert in male sexual function and fertility, joins Dr. Andrew Huberman to discuss a range of topics related to male sexual health. They address the debate surrounding the decline in sperm quality and testosterone levels over the years, suggesting that it remains controversial due to varying study results. Dr. Eisenberg emphasizes the need to focus on lifestyle factors that contribute to maintaining male fertility, such as avoiding heat exposure to the testicles, regular physical activity, and maintaining a healthy weight. They also discuss the impact of factors like environmental exposures, obesity, and drug use on sperm quality. The conversation touches on the effects of exogenous testosterone therapy on fertility and the risk of prostate cancer, with Dr. Eisenberg pointing out that there is no evidence linking testosterone therapy to an increased risk of prostate cancer. Finally, they discuss the impact of cycling, cannabis use, and sleep on male reproductive health, highlighting the importance of moderation and maintaining a healthy lifestyle.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# ...
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, neuroscientist Andrew Huberman discusses the topic of optimizing the brain and how to leverage neuroplasticity. He emphasizes that plasticity is not the goal itself, but rather a capacity for the brain to change. The real goal is to figure out what specific end goals or changes one wants to achieve and then use neuroplasticity to work towards those goals. Huberman explains the concept of short-term, medium-term, and long-term plasticity, and how they can be used to optimize learning and creativity. He shares his own daily routines and tools, emphasizing that everyone is different and needs to find what works best for them. Huberman also discusses the role of autonomic arousal and circadian rhythms in accessing plasticity. He emphasizes the importance of getting sunlight in the morning and evening to regulate the circadian clock and optimize alertness and sleep. He also discusses the relationship between alertness and creativity, explaining that very alert states are good for strategy implementation, while more relaxed and drowsy states are better for exploring novel configurations and creativity. Huberman also touches on the topics of exercise, diet, and the potential role of psychedelics in creativity. Overall, he provides valuable insights and tools for optimizing learning, creativity, and brain health.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this Huberman Lab podcast episode, Andrew Huberman discusses how to change your nervous system for the better and accelerate learning through behaviors such as incremental learning, making errors, and engaging the vestibular system to access neuroplasticity. Huberman explains that errors serve as a signal to the brain that a change needs to occur, and by embracing frustration and drilling deeper into the learning process, plasticity is accessed. He emphasizes the importance of incremental learning in shorter bouts to increase plasticity and the role of dopamine as motivation and reward in the learning process. Huberman also introduces the concept of limbic friction, a term he uses to describe the state of being too alert or tired and offers techniques like breathing exercises and manipulating autonomic arousal levels to find the optimal state for learning. Additionally, he highlights the role of balance and the vestibular system in accessing neuroplasticity by disrupting the vestibular motor relationship. Overall, Huberman provides insights into the mechanisms and behaviors that can improve learning and tap into neuroplasticity.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab podcast, Dr. Andrew Huberman discusses the topic of neuroplasticity. He explains that neuroplasticity refers to the brain and nervous system's ability to change in response to experience. This feature allows individuals to think differently, learn new things, and adapt to life situations. Huberman explains that neuroplasticity is most prominent in childhood, as the brain is wired for learning and can easily create new connections. However, after the age of 25, accessing neuroplasticity requires specific processes to create the changes. Huberman emphasizes the importance of recognizing what one wants to change or learn and creating a specific goal. He highlights that developmental plasticity occurs until the age of about 25, mainly through the removal of connections that don't serve our goals well. After this period, change requires a deliberate effort to change one's internal state in order to change the brain. Huberman discusses the role of neurotransmitters such as epinephrine and acetylcholine in accessing neuroplasticity. He explains how these chemicals promote alertness and focus and offers suggestions for increasing their levels, such as getting enough sleep, caffeine, and specific supplements. Additionally, Huberman emphasizes the importance of visual focus in accessing neuroplasticity, as mental focus follows visual focus. He recommends practicing visual focus by narrowing the gaze and focusing on a specific area or object. Finally, he suggests that combining behavioral practices with pharmacology or brain-machine interfaces can further enhance neuroplasticity.
#
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab podcast, Andrew Huberman discusses the importance of sleep and dreams in the process of learning and forgetting. He explains the different stages of sleep, such as slow-wave sleep (non-REM sleep) and REM sleep, and how they play a role in motor skill learning, the learning of detailed information, and the processing of emotional events. Huberman also explores the similarities between the effects of dreaming and clinical practices like EMDR and ketamine therapy for trauma. He suggests ways to optimize sleep, including maintaining a regular sleep schedule and engaging in resistance exercise, and advises against disruptions to sleep, like consuming alcohol or THC before bed. Huberman further touches on the topic of lucid dreaming and provides tools for increasing dream recall. Overall, he emphasizes the significance of sleep and the potential of leveraging it for optimal learning and emotional well-being.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab podcast, neurobiologist and ophthalmologist Andrew Huberman discusses strategies to combat jet lag, shift work, and sleeplessness. He emphasizes the importance of understanding the circadian rhythm, which regulates our feelings of wakefulness and sleepiness throughout a 24-hour cycle. Huberman explains that the key to combating jet lag is to get as much light as possible into your eyes during the day and as little light as possible at night. He suggests getting at least 100,000 lux of light exposure before 9:00 a.m., ideally from sunlight. Huberman also advises avoiding bright light exposure in the four to six hours before your temperature minimum, as this can delay your sleep-wake cycle. He explains that when traveling, it's essential to know your temperature minimum, as this helps determine the timing of light exposure. Huberman suggests shifting your circadian rhythm by getting light exposure after your temperature minimum to advance your clock, or before your temperature minimum to delay your clock. He recommends staying on the same schedule for at least 14 days, including weekends, and using light, temperature, exercise, and meals to help shift your circadian rhythms as needed. Huberman also discusses how melatonin can be used to induce sleepiness but advises using it responsibly, as it can have potential effects on hormone systems and puberty. Overall, Huberman emphasizes the importance of understanding the mechanisms behind sleep and circadian rhythms and using that knowledge to tailor strategies for optimal sleep and wakefulness.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Professor Andrew Huberman answers questions from listeners on various topics related to sleep, learning, and metabolism. He provides insights into the role of moonlight, firelight, and candlelight in setting circadian rhythms, explaining that they do not reset the circadian clock at night. The sensitivity of the melanopsin retinal cells changes throughout the day, and they will not activate the triggers in the brain that convey daytime signals when exposed to moonlight or firelight. Huberman also discusses the use of red light for mitochondrial repair in photoreceptor cells and the potential benefits of light delivered through the ears, nostrils, or roof of the mouth. He emphasizes that these methods may modulate biological processes, but do not directly mediate them. Additionally, Huberman delves into the effects of seasonal changes on mood, metabolism, and sleep. He explains that day length affects the duration of the melatonin signal, which in turn impacts various biological functions. Huberman suggests getting adequate sunlight and avoiding bright light at night throughout the year to optimize mood and metabolism. He also discusses the role of exercise in sleep and learning, mentioning that the best timing for exercise depends on individual preferences and goals. Huberman highlights the importance of specificity when discussing nootropics, as cognitive abilities encompass a range of factors such as focus, memory, creativity, and strategy development. He delves into the potential benefits and drawbacks of certain supplements and recommends examining reliable sources for more information. Moreover, Huberman explores the role of temperature in sleep, explaining that body temperature tends to be lowest around 4 a.m. and peaks between 4 and 6 p.m. Entrainment to external cues like light and exercise helps synchronize the internal temperature rhythm with the desired pattern. Finally, he touches on the effects of temperature on metabolism and the potential benefits of non-sleep deep rest and short 20-minute naps in enhancing learning and neuroplasticity. Overall, Andrew Huberman provides scientific insights and suggestions for optimizing sleep, learning, and metabolism through various strategies and approaches.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this Huberman Lab podcast episode, titled "Master Your Sleep & Be More Alert When Awake," Andrew Huberman, a professor of neurobiology and ophthalmology at Stanford School of Medicine, discusses the importance of sleep and wakefulness in our mental and physical health. He explains how adenosine, a molecule that builds up in our nervous system and body the longer we are awake, creates a sleep drive or hunger for sleep. Caffeine acts as an adenosine antagonist, blocking the sleepy signal and increasing dopamine levels to make us feel more awake and alert. Huberman emphasizes the significant role of sunlight in regulating our sleep-wake cycle and recommends getting sunlight exposure early in the day and avoiding bright light exposure at night to properly align our cortisol and melatonin rhythms. He also highlights the negative effects of light in the middle of the night, which suppress the release of dopamine and disrupt sleep patterns. Huberman suggests tools such as napping, meditation, hypnosis, and yoga nidra to help relax the mind, transition into sleep, and improve sleep quality. Lastly, he advises experimenting with caffeine intake and finding individual tolerance levels to optimize sleep. Overall, Huberman encourages listeners to establish consistent light exposure behaviors and anchor their circadian rhythms for better sleep and wakefulness patterns, promoting overall well-being.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Andrew Huberman, a professor of neurobiology and ophthalmology at Stanford School of Medicine, delves into the workings and changes of the nervous system. He explains that the nervous system includes the brain, spinal cord, and their connections to the organs of the body. He highlights the importance of understanding the different aspects of the nervous system, such as sensations, perceptions, emotions, thoughts, and actions, and how they all play a role in shaping our experiences and behaviors. Huberman emphasizes the role of electrical activity in neurons and neurotransmitters in the communication between nerve cells. He discusses the historical roots of our understanding of the nervous system, including discoveries made during wartime injuries. Huberman also explores the concept of neuroplasticity, the brain's ability to change and adapt, and how it is influenced by neuromodulators like dopamine and serotonin. He highlights the importance of attention and perception in harnessing neuroplasticity and the role of sleep in consolidating and solidifying the changes in the nervous system. Huberman concludes by introducing the autonomic nervous system and the importance of understanding its role in transitioning between alertness and calmness. He discusses the significance of ultradian rhythms, particularly the 90-minute cycles, in optimizing focus, learning, and creativity. Huberman suggests that mastering these rhythms can help individuals take control of their nervous system and enhance their sleep quality, ability to focus, and engagement in neuroplasticity. He also notes that future episodes of the podcast will delve deeper into these topics, providing more tools and techniques for improving our nervous system.
# ----------------------------------------------------------------------------------------------------
# GUEST: Andrew Huberman
# In this episode of the Huberman Lab Podcast, Andrew Huberman, a professor of neurobiology and ophthalmology at Stanford School of Medicine, introduces the podcast and its unique format. Unlike most podcasts, where each episode covers different topics, the Huberman Lab Podcast focuses on one topic for an entire month. Each month, Andrew and his guests will dive deep into a specific scientific topic and discuss the underlying science, tools, and barriers related to that topic.
#
# Listeners are encouraged to actively participate by suggesting topics and providing feedback in the comment section. Andrew pays close attention to the comments and likes, allowing the audience to shape the direction of the podcast. The podcast also covers a range of tools for enhancing one's nervous system, including behavioral tools, nutrition, supplementation, prescription drugs, and brain-machine interface devices.
#
# Andrew's large bulldog mastiff, Costello, also makes regular appearances on the podcast, often snoring in the background. In conclusion, Andrew expresses his gratitude for the audience's interest in science and looks forward to their continued engagement in future episodes.
# ----------------------------------------------------------------------------------------------------

# %%
FileIO.save_as_json('../../data/short_summaries.json', final)
# Out:
# 2024-04-26 04:36:28.667 | INFO     | src.preprocessor.preprocessing:save_as_json:111 - Data saved as json file here: ../../data/short_summaries.json

# %% [markdown]
# ### Combine Metadata

# %%
raw_data = FileIO().load_json('../../data/huberman_labs.json')

# %%
raw_data[0]['summary']
# Out:
# 'In this episode of the Huberman Lab podcast, Andrew Huberman interviews Dr. Matthew Walker, a professor of neuroscience and psychology, and the director of the Center for Sleep Science at the University of California, Berkeley. The episode marks the beginning of a six-episode series on sleep. In this episode, they discuss the importance of sleep and what happens when we don\'t get enough quality sleep. They also touch on the different sleep stages, such as non-rapid eye movement (non-REM) sleep and rapid eye movement (REM) sleep. They explore the theory that yawning is a way for the brain to cool down and the impact of body position on sleep. They also discuss the concept of "great sleep" versus "mediocre sleep" and the consequences of not getting enough quality sleep. Overall, the episode provides a comprehensive introduction to the topic of sleep and sets the stage for the upcoming episodes in the series, which will cover various aspects of sleep and offer practical tools for improving sleep.'

# %%
for i, d in enumerate(raw_data):
    d['summary'] = final[i]

# %%
raw_data[-1]['summary']
# Out:
# "In the inaugural episode of the Huberman Lab Podcast, host Andrew Huberman, a Stanford professor, introduces the show's unique approach to exploring neuroscience and its applications in daily life. The podcast will delve deeply into a single scientific topic each month, discussing the latest research, unknowns, and practical tools for improvement in areas such as motivation, focus, and other aspects of brain function. Huberman highlights the podcast's interactive nature, encouraging listener participation through comments and suggestions, which will guide future content. Additionally, he outlines the types of tools to be discussed, ranging from behavioral practices to technological interventions. Lastly, Huberman introduces his bulldog mastiff, Costello, as a quirky background presence in the podcast."

# %%
FileIO.save_as_json('../../data/huberman_labs.json', raw_data, overwrite=True)
# Out:
# 2024-04-26 04:38:38.802 | INFO     | src.preprocessor.preprocessing:save_as_json:111 - Data saved as json file here: ../../data/huberman_labs.json
# Bad pipe message: %s [b"\x0f\xdb \xcdQwm\x91Y\xa9\xc0\x17\x99+\xdf\xb0\xb6\xac\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d"]
# Bad pipe message: %s [b"cl'%>\xab\xcaoch\xb8<\xa1\xce\xe0\xe0\x86w\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00"]
# Bad pipe message: %s [b'\xc6\x14\x92\xcf\xdd\xc5l6\xbf]\xbb\xd3\x15k\x97o\xec:\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x00', b'\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e']
# Bad pipe message: %s [b'G\xb9\x9fO#\xdf\x9cBO\x1a\xc4<\xd0\xa7\x88R\x94\xff\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00', b'\x0c\x00\x00\t127.0.0.1']
# Bad pipe message: %s [b"R\x9b^,0i=(\xf4XX\xbdW\xab\xe0\xc4\x1f\xc7\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x00", b'2\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b"-\xab\xa8a\xb8\xa7\xaa\xbf\xaeM\xa0\xff\x98\xb6\xfaz\x12[\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c"]

# %% [markdown]
# ## Rearrange ordering of data keys

# %%
#separate contents
contents = [d['content'] for d in raw_data]

# %%
#create list of dicts with content removed
others = [{k:v for k,v in d.items() if k != 'content'} for d in raw_data]

# %%
#update list of dicts with content added back in 
[d.update(content=contents[i]) for i, d in enumerate(others)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
FileIO().save_as_json('../../data/huberman_labs.json', others, overwrite=True)
# Out:
# 2024-04-17 11:35:05.098 | INFO     | src.preprocessor.preprocessing:save_as_json:107 - Data saved as json file here: ../../data/huberman_labs.json
